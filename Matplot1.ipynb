# %% [markdown]
# <a href="https://colab.research.google.com/github/Bidyut-Sharma/final-sp-project/blob/main/Matplot1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y)

# %%
fig,ax=plt.subplots()
ax.plot(x,y)

# %%
#matplotlib exmple workflow
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#prepaare data
x=[6,7,8,9]
y=[66,77,88,99]
fig,ax=plt.subplots(figsize=(4,5))

# %%
#plot data
# customise data
ax.set(title="simple plot",
       xlabel="x-axis",
       ylabel="y-axis")

#save figure
plt.savefig('Figures\sample.plot.png')

# %%
x=np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
#x=y2 graph
fig,ax=plt.subplots(figsize=(4,5))
ax.plot(x,x**2)

# %%
fig,ax=plt.subplots(figsize=(4,5))
ax.scatter(x,np.exp(x))

# %%
fig,ax=plt.subplots(figsize=(4,5))
ax.plot(x,np.exp(x))

# %%
fig,ax=plt.subplots(figsize=(4,5))
ax.scatter(x,np.sin(x))

# %%
x=np.random.randn(1000)
fig,ax=plt.subplots(figsize=(4,5))
ax.hist(x)
# Out:
# (array([  8.,  38.,  93., 216., 262., 232., 112.,  30.,   7.,   2.]),
#  array([-3.18270015, -2.49951502, -1.8163299 , -1.13314478, -0.44995966,
#          0.23322547,  0.91641059,  1.59959571,  2.28278083,  2.96596595,
#          3.64915108]),
#  <a list of 10 Patch objects>)

# %%
df= pd.read_csv("/content/drive/MyDrive/sp project 2/hour.csv")

# %%
df
# Out:
#        instant      dteday  season  yr  ...  windspeed  casual  registered  cnt
# 0            1  2011-01-01       1   0  ...     0.0000       3          13   16
# 1            2  2011-01-01       1   0  ...     0.0000       8          32   40
# 2            3  2011-01-01       1   0  ...     0.0000       5          27   32
# 3            4  2011-01-01       1   0  ...     0.0000       3          10   13
# 4            5  2011-01-01       1   0  ...     0.0000       0           1    1
# ...        ...         ...     ...  ..  ...        ...     ...         ...  ...
# 17374    17375  2012-12-31       1   1  ...     0.1642      11         108  119
# 17375    17376  2012-12-31       1   1  ...     0.1642       8          81   89
# 17376    17377  2012-12-31       1   1  ...     0.1642       7          83   90
# 17377    17378  2012-12-31       1   1  ...     0.1343      13          48   61
# 17378    17379  2012-12-31       1   1  ...     0.1343      12          37   49
#
# ...
